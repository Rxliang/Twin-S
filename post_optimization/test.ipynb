# %%
import cv2
import numpy as np
import open3d as o3d
import matplotlib.pyplot as plt
from natsort import natsorted
import os
import time
import sys
import copy

# %% [markdown]
# **Generate pointcloud from the disparity maps and filter the pointcloud by depth.**

# %%
disparity_dir = '../../optimization_data/disp'
save_dir = '../../optimization_data/pointcloud'
Q = np.load('../params/Q.npy')
count = 0
start = time.time()
# Define the depth threshold
depth_threshold = 0.25 # meters

# Sequence of images from the left/right dir
disparities = natsorted([os.path.join(disparity_dir, f) for f in os.listdir(disparity_dir) if ".npy" in f])

for disp_map in disparities:
    disp = np.load(disp_map)
    point_cloud = cv2.reprojectImageTo3D(disp, Q)
    point_cloud = point_cloud.reshape(-1, 3)

    # Filter out the points beyond the depth threshold
    filtered_point_cloud = point_cloud[abs(point_cloud[:, 2]) < abs(depth_threshold)]

    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(filtered_point_cloud)
    # o3d.visualization.draw_geometries([pcd])
    save_path = os.path.join(save_dir, f'{count}.ply')
    o3d.io.write_point_cloud(save_path, pcd)
    print('Finished saving: '+f'{count}.ply')
    
    count += 1
end = time.time()
print(f'Done with pointcloud saving in {end - start}s')
# Out:
# [[ 1.00000000e+00  0.00000000e+00  0.00000000e+00 -9.36040771e+02]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00 -5.11093964e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.44359363e+03]
#  [ 0.00000000e+00  0.00000000e+00 -1.58730159e+01  0.00000000e+00]]
# Finished saving: 0.ply
# Finished saving: 1.ply
# Finished saving: 2.ply
# Finished saving: 3.ply
# Finished saving: 4.ply
# Finished saving: 5.ply
# Finished saving: 6.ply
# Finished saving: 7.ply
# Finished saving: 8.ply
# Finished saving: 9.ply
# Finished saving: 10.ply
# Finished saving: 11.ply
# Finished saving: 12.ply
# Finished saving: 13.ply
# Finished saving: 14.ply
# Finished saving: 15.ply
# Finished saving: 16.ply
# Finished saving: 17.ply
# Finished saving: 18.ply
# Finished saving: 19.ply
# Finished saving: 20.ply
# Finished saving: 21.ply
# Finished saving: 22.ply
# Finished saving: 23.ply
# Finished saving: 24.ply
# Finished saving: 25.ply
# Finished saving: 26.ply
# Finished saving: 27.ply
# Finished saving: 28.ply
# Finished saving: 29.ply
# Finished saving: 30.ply
# Finished saving: 31.ply
# Finished saving: 32.ply
# Finished saving: 33.ply
# Finished saving: 34.ply
# Finished saving: 35.ply
# Finished saving: 36.ply
# Finished saving: 37.ply
# Finished saving: 38.ply
# Finished saving: 39.ply
# Finished saving: 40.ply
# Finished saving: 41.ply
# Finished saving: 42.ply
# Finished saving: 43.ply
# Finished saving: 44.ply
# Finished saving: 45.ply
# Finished saving: 46.ply
# Finished saving: 47.ply
# Finished saving: 48.ply
# Finished saving: 49.ply
# Finished saving: 50.ply
# Finished saving: 51.ply
# Finished saving: 52.ply
# Finished saving: 53.ply
# Finished saving: 54.ply
# Finished saving: 55.ply
# Finished saving: 56.ply
# Finished saving: 57.ply
# Finished saving: 58.ply
# Finished saving: 59.ply
# Finished saving: 60.ply
# Finished saving: 61.ply
# Finished saving: 62.ply
# Finished saving: 63.ply
# Finished saving: 64.ply
# Finished saving: 65.ply
# Finished saving: 66.ply
# Finished saving: 67.ply
# Finished saving: 68.ply
# Finished saving: 69.ply
# Finished saving: 70.ply
# Finished saving: 71.ply
# Finished saving: 72.ply
# Finished saving: 73.ply
# Finished saving: 74.ply
# Finished saving: 75.ply
# Finished saving: 76.ply
# Finished saving: 77.ply
# Finished saving: 78.ply
# Finished saving: 79.ply
# Finished saving: 80.ply
# Finished saving: 81.ply
# Finished saving: 82.ply
# Finished saving: 83.ply
# Finished saving: 84.ply
# Finished saving: 85.ply
# Finished saving: 86.ply
# Finished saving: 87.ply
# Finished saving: 88.ply
# Finished saving: 89.ply
# Finished saving: 90.ply
# Finished saving: 91.ply
# Finished saving: 92.ply
# Finished saving: 93.ply
# Finished saving: 94.ply
# Finished saving: 95.ply
# Finished saving: 96.ply
# Finished saving: 97.ply
# Finished saving: 98.ply
# Finished saving: 99.ply
# Finished saving: 100.ply
# Finished saving: 101.ply
# Finished saving: 102.ply
# Finished saving: 103.ply
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\HONGCH~1\AppData\Local\Temp/ipykernel_32892/3707044649.py in <module>
#      20
#      21     pcd = o3d.geometry.PointCloud()
# ---> 22     pcd.points = o3d.utility.Vector3dVector(filtered_point_cloud)
#      23     # o3d.visualization.draw_geometries([pcd])
#      24     save_path = os.path.join(save_dir, f'{count}.ply')
#
# KeyboardInterrupt:

# %%
# pcd = o3d.io.read_point_cloud('../data/phantom_point-cloud_data/phacon_exp_3.ply')
# o3d.visualization.draw_geometries([pcd])

# %% [markdown]
# **Do phantom registration for all pointcloud**

# %%
sys.path.append('../')
sys.path.insert(0, '../optical_tracking')
sys.path.insert(0, '../util')
from phantom_registration import manual_registration, draw_registration_result
from Solver import solver
sol = solver()

# %%
def phantom_registration(pointcloud_dir):

    pcd_source_init = o3d.io.read_point_cloud("../../optimization_data/pointcloud/33.ply")
    pcd_target = o3d.io.read_point_cloud("../data/phantom_point-cloud_data/phacon_exp_3.ply")
    pcd_target = pcd_target.voxel_down_sample(voxel_size=0.001)
    cam2ph_list = []

    # manual registration to initialize
    result = manual_registration(pcd_source_init, pcd_target)
    pointclouds = natsorted([os.path.join(pointcloud_dir, f) for f in os.listdir(pointcloud_dir) if ".ply" in f])

    print("Apply point-to-plane ICP")

    for pointcloud in pointclouds:
        pcd_source = o3d.io.read_point_cloud(pointcloud)
        
        o3d.visualization.draw_geometries([pcd_target, pcd_source])
        break
        threshold = 0.0008

        trans_init_icp = result.transformation

        result = o3d.pipelines.registration.registration_icp(
            pcd_source, pcd_target, threshold, trans_init_icp,
            o3d.pipelines.registration.TransformationEstimationPointToPlane())

        print("Transformation is:")
        print(result.transformation)
        draw_registration_result(pcd_source, pcd_target, result.transformation)
        ph2cam = result.transformation
        cam2ph = sol.invTransformation(ph2cam)
        cam2ph_list.append(cam2ph)
        
        T_o_p = np.array(cam2ph_list)
        print(T_o_p.shape)
        if count == 5:
            break

    T_o_p = np.array(cam2ph_list)
    # np.save('T_o_p.npy', T_o_p)

# %%
pointcloud_dir = '../../optimization_data/pointcloud/'
phantom_registration(pointcloud_dir)
# Out:
# Visualization of two point clouds before manual alignment
#
# 1) Please pick at least three correspondences using [shift + left click]
#    Press [shift + right click] to undo point picking
# 2) After picking points, press 'Q' to close the window
#
#
# 1) Please pick at least three correspondences using [shift + left click]
#    Press [shift + right click] to undo point picking
# 2) After picking points, press 'Q' to close the window
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# C:\Users\HONGCH~1\AppData\Local\Temp/ipykernel_32892/1698384330.py in <module>
#       1 pointcloud_dir = '../../optimization_data/pointcloud/'
# ----> 2 phantom_registration(pointcloud_dir)
#
# C:\Users\HONGCH~1\AppData\Local\Temp/ipykernel_32892/3280965148.py in phantom_registration(pointcloud_dir)
#       7
#       8     # manual registration to initialize
# ----> 9     result = manual_registration(pcd_source_init, pcd_target)
#      10     pointclouds = natsorted([os.path.join(pointcloud_dir, f) for f in os.listdir(pointcloud_dir) if ".ply" in f])
#      11
#
# c:\Users\Hongchao Shu\Desktop\CIS II\RoboMaster\post_optimization\../optical_tracking\phantom_registration.py in manual_registration(source, target)
#     126     picked_id_source = pick_points(source)
#     127     picked_id_target = pick_points(target)
# --> 128     assert (len(picked_id_source) >= 3 and len(picked_id_target) >= 3)
#     129     assert (len(picked_id_source) == len(picked_id_target))
#     130     corr = np.zeros((len(picked_id_source), 2))
#
# AssertionError:
